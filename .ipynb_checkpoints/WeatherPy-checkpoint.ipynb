# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url= "http://api.openweathermap.org/data/2.5/weather"
units = "imperial"

city_name = []
print("-----------------------------------------")
print("Beginning Data Retrieval")
print("-----------------------------------------\n")
for city in cities:
    response = requests.get(url, params={ "q": city, "APPID": api_key, "units": units })
    if response.status_code == 200:
        formatted_response = response.json()
        city_name.append(formatted_response)
        print(f"Processing Record {cities.index(city)} of {city}")

    else:
        print("Cannot find a city.")
print("-----------------------------------------")
print("Data Retrieval Complete")
print("-----------------------------------------")
# Out:
# -----------------------------------------
# Beginning Data Retrieval
# -----------------------------------------
#
# Processing Record 0 of beloha
# Processing Record 1 of dingle
# Processing Record 2 of albany
# Processing Record 3 of kirakira
# Processing Record 4 of bredasdorp
# Processing Record 5 of yatou
# Processing Record 6 of hobart
# Processing Record 7 of rio gallegos
# Processing Record 8 of puerto ayora
# Processing Record 9 of nioki
# Processing Record 10 of adrar
# Processing Record 11 of faanui
# Processing Record 12 of boa vista
# Processing Record 13 of punta arenas
# Processing Record 14 of ushuaia
# Processing Record 15 of hasaki
# Processing Record 16 of deputatskiy
# Processing Record 17 of kalmunai
# Processing Record 18 of victor harbor
# Processing Record 19 of tasiilaq
# Processing Record 20 of charters towers
# Processing Record 21 of comodoro rivadavia
# Processing Record 22 of akdepe
# Processing Record 23 of thinadhoo
# Processing Record 24 of breves
# Processing Record 25 of yellowknife
# Processing Record 26 of jamestown
# Processing Record 27 of bluff
# Processing Record 28 of cape town
# Processing Record 29 of abha
# Processing Record 30 of busselton
# Processing Record 31 of bahia blanca
# Processing Record 32 of rikitea
# Cannot find a city.
# Processing Record 34 of la primavera
# Processing Record 35 of nouakchott
# Processing Record 36 of butaritari
# Processing Record 37 of biak
# Processing Record 38 of iqaluit
# Cannot find a city.
# Processing Record 40 of gorahun
# Processing Record 41 of liverpool
# Processing Record 42 of vostok
# Processing Record 43 of carnarvon
# Processing Record 44 of narsaq
# Processing Record 45 of port hardy
# Processing Record 46 of saint anthony
# Processing Record 47 of jiujiang
# Cannot find a city.
# Processing Record 49 of pochutla
# Cannot find a city.
# Processing Record 51 of tiksi
# Cannot find a city.
# Processing Record 53 of jalu
# Processing Record 54 of charleston
# Processing Record 55 of mataura
# Processing Record 56 of vaini
# Processing Record 57 of sao joao da barra
# Cannot find a city.
# Processing Record 59 of fortuna
# Processing Record 60 of boyolangu
# Processing Record 61 of clyde river
# Processing Record 62 of snezhnogorsk
# Processing Record 63 of beyneu
# Processing Record 64 of aksarka
# Processing Record 65 of uricani
# Processing Record 66 of glace bay
# Processing Record 67 of esperance
# Processing Record 68 of el alto
# Processing Record 69 of madanapalle
# Processing Record 70 of caruray
# Cannot find a city.
# Processing Record 72 of port alfred
# Processing Record 73 of savonlinna
# Processing Record 74 of constantine
# Processing Record 75 of santiago
# Processing Record 76 of bethel
# Processing Record 77 of hermanus
# Processing Record 78 of pangnirtung
# Processing Record 79 of cherskiy
# Cannot find a city.
# Processing Record 81 of mapastepec
# Processing Record 82 of namatanai
# Processing Record 83 of bandarbeyla
# Cannot find a city.
# Processing Record 85 of hilo
# Processing Record 86 of manggar
# Processing Record 87 of nikolskoye
# Processing Record 88 of qaanaaq
# Processing Record 89 of hambantota
# Processing Record 90 of vila velha
# Processing Record 91 of moba
# Processing Record 92 of prince albert
# Processing Record 93 of ponta do sol
# Processing Record 94 of huarmey
# Processing Record 95 of batangafo
# Processing Record 96 of sheridan
# Processing Record 97 of kodino
# Processing Record 98 of xining
# Processing Record 99 of martapura
# Processing Record 100 of bubaque
# Processing Record 101 of lebu
# Cannot find a city.
# Cannot find a city.
# Cannot find a city.
# Processing Record 105 of avera
# Processing Record 106 of tuktoyaktuk
# Processing Record 107 of san patricio
# Processing Record 108 of lapeer
# Processing Record 109 of leh
# Processing Record 110 of kibala
# Processing Record 111 of aitape
# Processing Record 112 of ketchikan
# Cannot find a city.
# Processing Record 114 of buraydah
# Processing Record 115 of avarua
# Processing Record 116 of gerash
# Processing Record 117 of khash
# Processing Record 118 of patos
# Processing Record 119 of chokurdakh
# Processing Record 120 of kapaa
# Processing Record 121 of dikson
# Processing Record 122 of ilhabela
# Processing Record 123 of saint-philippe
# Processing Record 124 of nakhon nayok
# Processing Record 125 of ivnya
# Processing Record 126 of cabo san lucas
# Cannot find a city.
# Processing Record 128 of horsham
# Processing Record 129 of lasa
# Processing Record 130 of hamilton
# Cannot find a city.
# Processing Record 132 of kaitangata
# Processing Record 133 of mar del plata
# Cannot find a city.
# Processing Record 135 of plast
# Processing Record 136 of rajshahi
# Processing Record 137 of petropavlovsk-kamchatskiy
# Processing Record 138 of sobolevo
# Processing Record 139 of amurzet
# Processing Record 140 of ilulissat
# Processing Record 141 of arraial do cabo
# Processing Record 142 of blackwater
# Processing Record 143 of north bend
# Processing Record 144 of sabang
# Processing Record 145 of severo-kurilsk
# Processing Record 146 of laguna
# Processing Record 147 of sur
# Processing Record 148 of axim
# Processing Record 149 of hualmay
# Processing Record 150 of cidreira
# Processing Record 151 of baculin
# Processing Record 152 of yenotayevka
# Processing Record 153 of vestmannaeyjar
# Processing Record 154 of airai
# Processing Record 155 of san cristobal
# Processing Record 156 of sao filipe
# Processing Record 157 of yangliuqing
# Cannot find a city.
# Processing Record 159 of ingham
# Processing Record 160 of waipawa
# Processing Record 161 of galveston
# Processing Record 162 of imbituba
# Processing Record 163 of xihe
# Processing Record 164 of touros
# Processing Record 165 of atuona
# Processing Record 166 of reserva
# Cannot find a city.
# Processing Record 168 of rio cuarto
# Processing Record 169 of cabedelo
# Processing Record 170 of castro
# Cannot find a city.
# Processing Record 172 of kodiak
# Processing Record 173 of alofi
# Processing Record 174 of puerto colombia
# Processing Record 175 of pevek
# Cannot find a city.
# Processing Record 177 of east london
# Processing Record 178 of fethiye
# Processing Record 179 of peniche
# Processing Record 180 of half moon bay
# Processing Record 181 of longyearbyen
# Cannot find a city.
# Processing Record 183 of pisco
# Processing Record 184 of saskylakh
# Cannot find a city.
# Processing Record 186 of belyy yar
# Processing Record 187 of kamarion
# Processing Record 188 of bilma
# Processing Record 189 of ahipara
# Processing Record 190 of bambous virieux
# Processing Record 191 of ugoofaaru
# Processing Record 192 of camacupa
# Processing Record 193 of estelle
# Processing Record 194 of limon
# Processing Record 195 of codrington
# Processing Record 196 of samarai
# Processing Record 197 of meulaboh
# Processing Record 198 of parrita
# Cannot find a city.
# Processing Record 200 of marzuq
# Processing Record 201 of marawi
# Processing Record 202 of arawa
# Processing Record 203 of thompson
# Cannot find a city.
# Cannot find a city.
# Processing Record 206 of roald
# Processing Record 207 of vila franca do campo
# Processing Record 208 of salalah
# Processing Record 209 of barrow
# Processing Record 210 of uige
# Processing Record 211 of ahuimanu
# Processing Record 212 of gladstone
# Cannot find a city.
# Processing Record 214 of tevaitoa
# Processing Record 215 of orsha
# Processing Record 216 of helena
# Processing Record 217 of kavaratti
# Processing Record 218 of tezu
# Processing Record 219 of aklavik
# Processing Record 220 of kargil
# Processing Record 221 of tuatapere
# Processing Record 222 of victoria
# Processing Record 223 of faya
# Processing Record 224 of liku
# Processing Record 225 of hofn
# Processing Record 226 of rio verde de mato grosso
# Processing Record 227 of waingapu
# Processing Record 228 of sitka
# Processing Record 229 of poum
# Processing Record 230 of villarrica
# Processing Record 231 of najran
# Processing Record 232 of port elizabeth
# Processing Record 233 of georgetown
# Processing Record 234 of college
# Processing Record 235 of calmar
# Processing Record 236 of flinders
# Cannot find a city.
# Processing Record 238 of nemuro
# Cannot find a city.
# Processing Record 240 of porto velho
# Processing Record 241 of leningradskiy
# Cannot find a city.
# Cannot find a city.
# Processing Record 244 of khasan
# Processing Record 245 of floro
# Cannot find a city.
# Processing Record 247 of berlevag
# Processing Record 248 of mahebourg
# Processing Record 249 of hami
# Processing Record 250 of waitati
# Processing Record 251 of kruisfontein
# Processing Record 252 of gijon
# Processing Record 253 of aksay
# Processing Record 254 of katsuura
# Processing Record 255 of ca mau
# Processing Record 256 of hithadhoo
# Processing Record 257 of traverse city
# Processing Record 258 of aquiraz
# Processing Record 259 of saint-leu
# Processing Record 260 of presidente medici
# Processing Record 261 of yamada
# Processing Record 262 of gazanjyk
# Processing Record 263 of aksu
# Processing Record 264 of pontianak
# Cannot find a city.
# Processing Record 266 of chuy
# Processing Record 267 of nanchang
# Processing Record 268 of honiara
# Processing Record 269 of port macquarie
# Processing Record 270 of khatassy
# Processing Record 271 of geraldton
# Processing Record 272 of naze
# Processing Record 273 of cap malheureux
# Processing Record 274 of griffith
# Processing Record 275 of shirokiy
# Processing Record 276 of fort walton beach
# Processing Record 277 of puerto narino
# Processing Record 278 of kizukuri
# Processing Record 279 of xingyi
# Processing Record 280 of malindi
# Processing Record 281 of vardo
# Processing Record 282 of gat
# Processing Record 283 of barcelos
# Processing Record 284 of itacare
# Processing Record 285 of lompoc
# Processing Record 286 of zapolyarnyy
# Processing Record 287 of kavieng
# Cannot find a city.
# Processing Record 289 of churapcha
# Processing Record 290 of iquitos
# Processing Record 291 of grindavik
# Processing Record 292 of khatanga
# Processing Record 293 of ialibu
# Processing Record 294 of torbay
# Cannot find a city.
# Processing Record 296 of gao
# Processing Record 297 of lakhimpur
# Processing Record 298 of mizdah
# Cannot find a city.
# Processing Record 300 of kawalu
# Processing Record 301 of new norfolk
# Processing Record 302 of esna
# Processing Record 303 of aldama
# Processing Record 304 of bilibino
# Processing Record 305 of nome
# Processing Record 306 of northam
# Processing Record 307 of yumen
# Processing Record 308 of fort nelson
# Processing Record 309 of prachuap khiri khan
# Processing Record 310 of port-gentil
# Processing Record 311 of arlit
# Processing Record 312 of ulladulla
# Processing Record 313 of iisalmi
# Processing Record 314 of rio grande city
# Processing Record 315 of lima
# Cannot find a city.
# Processing Record 317 of chapais
# Processing Record 318 of uvelskiy
# Processing Record 319 of hailey
# Processing Record 320 of ormara
# Cannot find a city.
# Processing Record 322 of sabha
# Processing Record 323 of bowen
# Processing Record 324 of udachnyy
# Cannot find a city.
# Processing Record 326 of beinamar
# Processing Record 327 of sungairaya
# Processing Record 328 of port blair
# Processing Record 329 of saint-louis
# Processing Record 330 of vengerovo
# Cannot find a city.
# Processing Record 332 of orkney
# Processing Record 333 of tura
# Processing Record 334 of kichmengskiy gorodok
# Processing Record 335 of matara
# Processing Record 336 of trincomalee
# Processing Record 337 of tomatlan
# Processing Record 338 of auki
# Processing Record 339 of oussouye
# Processing Record 340 of nalut
# Processing Record 341 of scarborough
# Processing Record 342 of grand gaube
# Processing Record 343 of pijijiapan
# Processing Record 344 of camacha
# Processing Record 345 of ust-barguzin
# Cannot find a city.
# Processing Record 347 of san rafael
# Cannot find a city.
# Processing Record 349 of saint george
# Processing Record 350 of alghero
# Processing Record 351 of pandan
# Processing Record 352 of mount gambier
# Processing Record 353 of etchoropo
# Processing Record 354 of ribeira grande
# Processing Record 355 of yaan
# Cannot find a city.
# Processing Record 357 of lavrentiya
# Processing Record 358 of morondava
# Processing Record 359 of kabompo
# Processing Record 360 of acajutla
# Processing Record 361 of coreau
# Processing Record 362 of aswan
# Processing Record 363 of copiapo
# Processing Record 364 of acari
# Processing Record 365 of curuca
# Processing Record 366 of ambon
# Processing Record 367 of robertsport
# Cannot find a city.
# Processing Record 369 of alyangula
# Cannot find a city.
# Processing Record 371 of lipin bor
# Processing Record 372 of svetlogorsk
# Processing Record 373 of wainwright
# Processing Record 374 of cockburn town
# Processing Record 375 of khetri
# Processing Record 376 of ishigaki
# Cannot find a city.
# Processing Record 378 of bam
# Processing Record 379 of verkhoyansk
# Processing Record 380 of ayan
# Processing Record 381 of miri
# Processing Record 382 of talnakh
# Cannot find a city.
# Processing Record 384 of zhigansk
# Processing Record 385 of klaksvik
# Cannot find a city.
# Processing Record 387 of sandnessjoen
# Processing Record 388 of banepa
# Cannot find a city.
# Processing Record 390 of balikpapan
# Processing Record 391 of collie
# Processing Record 392 of duku
# Processing Record 393 of huallanca
# Processing Record 394 of bathsheba
# Processing Record 395 of la seyne-sur-mer
# Processing Record 396 of socorro
# Processing Record 397 of ixtapa
# Cannot find a city.
# Processing Record 399 of balagansk
# Cannot find a city.
# Processing Record 401 of ipixuna
# Processing Record 402 of eureka
# Processing Record 403 of ucluelet
# Processing Record 404 of wanning
# Processing Record 405 of la palma
# Processing Record 406 of buala
# Processing Record 407 of finschhafen
# Cannot find a city.
# Processing Record 409 of namibe
# Processing Record 410 of barentu
# Cannot find a city.
# Processing Record 412 of sioux lookout
# Cannot find a city.
# Processing Record 414 of norman wells
# Processing Record 415 of cooma
# Processing Record 416 of kahului
# Processing Record 417 of rafai
# Processing Record 418 of bunia
# Processing Record 419 of parintins
# Cannot find a city.
# Processing Record 421 of kansk
# Processing Record 422 of paamiut
# Processing Record 423 of luderitz
# Processing Record 424 of mayumba
# Processing Record 425 of broome
# Processing Record 426 of sola
# Processing Record 427 of agadez
# Processing Record 428 of lagoa
# Processing Record 429 of rapid valley
# Processing Record 430 of kudahuvadhoo
# Processing Record 431 of outjo
# Processing Record 432 of progreso
# Processing Record 433 of praia da vitoria
# Processing Record 434 of upernavik
# Processing Record 435 of angoche
# Processing Record 436 of evensk
# Processing Record 437 of necochea
# Processing Record 438 of saldanha
# Processing Record 439 of nuevitas
# Processing Record 440 of elizabeth city
# Processing Record 441 of puerto rondon
# Processing Record 442 of san quintin
# Processing Record 443 of saint-pierre
# Processing Record 444 of svencionys
# Cannot find a city.
# Processing Record 446 of ponta pora
# Processing Record 447 of ballina
# Processing Record 448 of vilyuysk
# Processing Record 449 of waddan
# Cannot find a city.
# Cannot find a city.
# Processing Record 452 of jurmala
# Processing Record 453 of jijiga
# Processing Record 454 of karasburg
# Processing Record 455 of brae
# Processing Record 456 of kizhinga
# Processing Record 457 of mahibadhoo
# Cannot find a city.
# Processing Record 459 of jinchang
# Processing Record 460 of hetauda
# Processing Record 461 of mezen
# Processing Record 462 of barabai
# Processing Record 463 of diebougou
# Processing Record 464 of carballo
# Processing Record 465 of bhuj
# Processing Record 466 of omsukchan
# Cannot find a city.
# Processing Record 468 of ust-maya
# Processing Record 469 of boende
# Cannot find a city.
# Processing Record 471 of provideniya
# Processing Record 472 of valparaiso
# Processing Record 473 of finnsnes
# Processing Record 474 of seoul
# Processing Record 475 of baykit
# Processing Record 476 of bordighera
# Processing Record 477 of san pedro
# Processing Record 478 of cleveland
# Processing Record 479 of luganville
# Processing Record 480 of batagay-alyta
# Processing Record 481 of kodinsk
# Processing Record 482 of shubarshi
# Processing Record 483 of kaseda
# Processing Record 484 of nerchinskiy zavod
# Processing Record 485 of zhangjiakou
# Processing Record 486 of nargana
# Processing Record 487 of nador
# Processing Record 488 of oparino
# Processing Record 489 of portland
# Processing Record 490 of saint-joseph
# Processing Record 491 of nova olimpia
# Processing Record 492 of palmer
# Processing Record 493 of mackenzie
# Processing Record 494 of caravelas
# Processing Record 495 of penarroya-pueblonuevo
# Processing Record 496 of atar
# Processing Record 497 of keita
# Processing Record 498 of avesta
# Processing Record 499 of yulara
# Processing Record 500 of platteville
# Processing Record 501 of araouane
# Processing Record 502 of royan
# Processing Record 503 of moranbah
# Processing Record 504 of sikonge
# Processing Record 505 of ushtobe
# Processing Record 506 of mayo
# Processing Record 507 of husavik
# Processing Record 508 of lamar
# Processing Record 509 of san juan
# Processing Record 510 of loralai
# Processing Record 511 of saint-augustin
# Processing Record 512 of piney green
# Processing Record 513 of bestobe
# Cannot find a city.
# Processing Record 515 of noumea
# Processing Record 516 of sao domingos
# Processing Record 517 of marica
# Processing Record 518 of sisimiut
# Cannot find a city.
# Processing Record 520 of corinto
# Cannot find a city.
# Cannot find a city.
# Processing Record 523 of ulaanbaatar
# Processing Record 524 of nikel
# Processing Record 525 of los llanos de aridane
# Processing Record 526 of severo-yeniseyskiy
# Cannot find a city.
# Processing Record 528 of nioro
# Processing Record 529 of dhidhdhoo
# Processing Record 530 of semnan
# Processing Record 531 of naryan-mar
# Processing Record 532 of henties bay
# Processing Record 533 of dunedin
# Processing Record 534 of san lawrenz
# Processing Record 535 of senneterre
# Processing Record 536 of amahai
# Processing Record 537 of kaeo
# Processing Record 538 of darlawn
# Processing Record 539 of catende
# Processing Record 540 of princeton
# Processing Record 541 of sivaki
# Cannot find a city.
# Processing Record 543 of sao joao evangelista
# Cannot find a city.
# Processing Record 545 of bayir
# Processing Record 546 of alcudia
# Cannot find a city.
# Processing Record 548 of rawson
# Processing Record 549 of lyuban
# Processing Record 550 of lusambo
# Processing Record 551 of emerald
# Processing Record 552 of santiago del estero
# Processing Record 553 of balabac
# Processing Record 554 of arti
# Cannot find a city.
# Processing Record 556 of batagay
# Processing Record 557 of lahij
# Processing Record 558 of borgarnes
# Processing Record 559 of aloleng
# Processing Record 560 of stavern
# Processing Record 561 of crestview
# Processing Record 562 of isangel
# Processing Record 563 of chingirlau
# Cannot find a city.
# Processing Record 565 of arzgir
# Processing Record 566 of veere
# Processing Record 567 of ojuelos de jalisco
# Processing Record 568 of shubarkuduk
# Processing Record 569 of russell
# Processing Record 570 of bay roberts
# Processing Record 571 of freeport
# Processing Record 572 of puro
# Processing Record 573 of bandundu
# Processing Record 574 of novoagansk
# Processing Record 575 of amapa
# Processing Record 576 of wajir
# Processing Record 577 of mareeba
# Processing Record 578 of yilan
# Processing Record 579 of port hedland
# Processing Record 580 of sant julia de loria
# Processing Record 581 of paoua
# Processing Record 582 of ust-omchug
# Processing Record 583 of pedasi
# Processing Record 584 of rochegda
# Processing Record 585 of atbasar
# Processing Record 586 of bakchar
# Processing Record 587 of acapulco
# Processing Record 588 of odesskoye
# Processing Record 589 of bangassou
# Processing Record 590 of guerrero negro
# Processing Record 591 of portel
# Processing Record 592 of harper
# Processing Record 593 of antofagasta
# Processing Record 594 of qaqortoq
# Processing Record 595 of hovd
# Processing Record 596 of ozinki
# Processing Record 597 of naberera
# Processing Record 598 of ancud
# Processing Record 599 of shenjiamen
# -----------------------------------------
# Data Retrieval Complete
# -----------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
print(city_name)
# Out:
# [{'coord': {'lon': 45.06, 'lat': -25.17}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 74.32, 'pressure': 1020.5, 'humidity': 64, 'temp_min': 74.32, 'temp_max': 74.32, 'sea_level': 1020.5, 'grnd_level': 999.01}, 'wind': {'speed': 9.4, 'deg': 136.794}, 'clouds': {'all': 64}, 'dt': 1569995567, 'sys': {'message': 0.0076, 'country': 'MG', 'sunrise': 1569983945, 'sunset': 1570028357}, 'timezone': 10800, 'id': 1067565, 'name': 'Beloha', 'cod': 200}, {'coord': {'lon': 122.67, 'lat': 11}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 85.6, 'pressure': 1009.95, 'humidity': 67, 'temp_min': 85.6, 'temp_max': 85.6, 'sea_level': 1009.95, 'grnd_level': 993.47}, 'wind': {'speed': 3.62, 'deg': 156.429}, 'rain': {'3h': 2.438}, 'clouds': {'all': 94}, 'dt': 1569995567, 'sys': {'message': 0.0057, 'country': 'PH', 'sunrise': 1569965881, 'sunset': 1570009177}, 'timezone': 28800, 'id': 1714733, 'name': 'Dingle', 'cod': 200}, {'coord': {'lon': -73.75, 'lat': 42.65}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 70.39, 'pressure': 1009, 'humidity': 69, 'temp_min': 64.99, 'temp_max': 75.2}, 'visibility': 16093, 'wind': {'speed': 8.05, 'deg': 270}, 'clouds': {'all': 75}, 'dt': 1569995567, 'sys': {'type': 1, 'id': 3273, 'message': 0.0085, 'country': 'US', 'sunrise': 1570013572, 'sunset': 1570055746}, 'timezone': -14400, 'id': 5106834, 'name': 'Albany', 'cod': 200}, {'coord': {'lon': 161.92, 'lat': -10.46}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 77.81, 'pressure': 1010.2, 'humidity': 86, 'temp_min': 77.81, 'temp_max': 77.81, 'sea_level': 1010.2, 'grnd_level': 1003.79}, 'wind': {'speed': 5.39, 'deg': 142.85}, 'rain': {'3h': 8}, 'clouds': {'all': 99}, 'dt': 1569995567, 'sys': {'message': 0.0061, 'country': 'SB', 'sunrise': 1569956162, 'sunset': 1570000060}, 'timezone': 39600, 'id': 2178753, 'name': 'Kirakira', 'cod': 200}, {'coord': {'lon': 20.04, 'lat': -34.53}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 54.72, 'pressure': 1015, 'humidity': 87, 'temp_min': 51.8, 'temp_max': 57}, 'wind': {'speed': 6.93, 'deg': 60}, 'clouds': {'all': 100}, 'dt': 1569995568, 'sys': {'type': 1, 'id': 1966, 'message': 0.006, 'country': 'ZA', 'sunrise': 1569989743, 'sunset': 1570034566}, 'timezone': 7200, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}, {'coord': {'lon': 9.81, 'lat': 3.63}, 'weather': [{'id': 200, 'main': 'Thunderstorm', 'description': 'thunderstorm with light rain', 'icon': '11d'}], 'base': 'stations', 'main': {'temp': 73.4, 'pressure': 1011, 'humidity': 100, 'temp_min': 73.4, 'temp_max': 73.4}, 'visibility': 6000, 'wind': {'speed': 2.24, 'deg': 10}, 'clouds': {'all': 75}, 'dt': 1569995568, 'sys': {'type': 1, 'id': 2090, 'message': 0.0071, 'country': 'CM', 'sunrise': 1569992862, 'sunset': 1570036357}, 'timezone': 3600, 'id': 2225940, 'name': 'Yatou', 'cod': 200}, {'coord': {'lon': 147.33, 'lat': -42.88}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 61.18, 'pressure': 1020, 'humidity': 51, 'temp_min': 59, 'temp_max': 63}, 'visibility': 10000, 'wind': {'speed': 16.11, 'deg': 140}, 'clouds': {'all': 0}, 'dt': 1569995441, 'sys': {'type': 1, 'id': 9545, 'message': 0.008, 'country': 'AU', 'sunrise': 1569959002, 'sunset': 1570004222}, 'timezone': 36000, 'id': 2163355, 'name': 'Hobart', 'cod': 200}, {'coord': {'lon': -69.22, 'lat': -51.62}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 35.6, 'pressure': 1016, 'humidity': 74, 'temp_min': 35.6, 'temp_max': 35.6}, 'visibility': 10000, 'wind': {'speed': 13.87, ' ...

# %%
# set up lists to hold reponse info
name= []
cloudiness =[]
country = []
date = []
humidity = []
lat = []
lng = []
temp = []
wind = []

# Building Dataframe
for cities in city_name:
    name.append(cities['name'])
    cloudiness.append(cities['clouds']['all'])
    country.append(cities['sys']['country'])
    date.append(cities['dt'])
    humidity.append(cities['main']['humidity'])
    lat.append(cities['coord']['lat'])
    lng.append(cities['coord']['lon'])
    temp.append(cities['main']['temp_max'])
    wind.append(cities['wind']['speed'])
    

weather_cities = pd.DataFrame({"City":name,
                          "Cloudiness": cloudiness,
                          "Country":country,
                          "Date":date,
                          "Humidity":humidity,
                          "Latitude":lat,
                          "Lng":lng,
                          "Max Temp":temp,
                          "Wind Speed":wind})

#export to csv file
weather_cities.to_csv("weather_data.csv")

weather_cities
# Out:
#                     City  Cloudiness Country        Date  Humidity  Latitude  \
# 0                 Beloha          64      MG  1569995567        64    -25.17
# 1                 Dingle          94      PH  1569995567        67     11.00
# 2                 Albany          75      US  1569995567        69     42.65
# 3               Kirakira          99      SB  1569995567        86    -10.46
# 4             Bredasdorp         100      ZA  1569995568        87    -34.53
# 5                  Yatou          75      CM  1569995568       100      3.63
# 6                 Hobart           0      AU  1569995441        51    -42.88
# 7           Rio Gallegos           0      AR  1569995568        74    -51.62
# 8           Puerto Ayora          75      EC  1569995568        94     -0.74
# 9                  Nioki         100      CD  1569995568        85     -2.72
# 10                 Adrar           0      DZ  1569995569        13     27.87
# 11                Faanui          47      PF  1569995569        78    -16.48
# 12             Boa Vista           0      BR  1569995332        74      2.82
# 13          Punta Arenas          75      CL  1569995569        75    -53.16
# 14               Ushuaia          40      AR  1569995281        69    -54.81
# 15                Hasaki          20      JP  1569995569        48     35.73
# 16           Deputatskiy         100      RU  1569995570        88     69.30
# 17              Kalmunai         100      LK  1569995570        50      7.42
# 18         Victor Harbor           0      AU  1569995570        72    -35.55
# 19              Tasiilaq          99      GL  1569995570        64     65.61
# 20       Charters Towers          48      AU  1569995570        39    -20.07
# 21    Comodoro Rivadavia           0      AR  1569995284        80    -45.87
# 22                Akdepe           0      TM  1569995571        26     42.05
# 23             Thinadhoo          79      MV  1569995571        75      0.53
# 24                Breves          40      BR  1569995571        94     -1.68
# 25           Yellowknife          20      CA  1569995307        86     62.45
# 26             Jamestown           0      AU  1569995571        17    -33.21
# 27                 Bluff          72      AU  1569995572        46    -23.58
# 28             Cape Town           0      ZA  1569995317        87    -33.93
# 29                  Abha           0      SA  1569995572        68     18.22
# ..                   ...         ...     ...         ...       ...       ...
# 500          Bay Roberts          90      CA  1569995672        75     47.58
# 501             Freeport          10      BS  1569995672        82     26.54
# 502                 Puro          81      PH  1569995672        73     13.13
# 503             Bandundu          56      CD  1569995672        87     -3.32
# 504           Novoagansk         100      RU  1569995672        93     61.94
# 505                Amapa          75      HN  1569995673        88     15.09
# 506                Wajir          66      KE  1569995673        62      1.75
# 507              Mareeba          40      AU  1569995673        54    -16.99
# 508                Yilan           0      CN  1569995673        46     43.11
# 509         Port Hedland           0      AU  1569995673        24    -20.31
# 510  Sant Julia de Loria          21      AD  1569995674        48     42.46
# 511                Paoua         100      CF  1569995674        95      7.24
# 512           Ust-Omchug         100      RU  1569995674        94     61.13
# 513               Pedasi          88      PA  1569995674        91      7.53
# 514             Rochegda          90      RU  1569995674        80     62.67
# 515              Atbasar          80      KZ  1569995675        43     51.81
# 516              Bakchar          74      RU  1569995675        53     57.02
# 517             Acapulco          20      MX  1569995675        88     16.86
# 518            Odesskoye          29      RU  1569995675        45     54.21
# 519            Bangassou         100      CF  1569995675        94      4.74
# 520       Guerrero Negro           0      MX  1569995676        78     27.97
# 521               Portel          69      BR  1569995676        91     -1.94
# 522               Harper          75      US  1569995676        78     30.30
# 523          Antofagasta          75      CL  1569995676        87    -23.65
# 524             Qaqortoq         100      GL  1569995677        27     60.72
# 525                 Hovd          40      NO  1569995677       100     63.83
# 526               Ozinki          98      RU  1569995677        81     51.20
# 527             Naberera          77      TZ  1569995677        67     -4.20
# 528                Ancud           0      CL  1569995677        87    -41.87
# 529           Shenjiamen          48      CN  1569995678        83     29.96
#
#         Lng  Max Temp  Wind Speed
# 0     45.06     74.32        9.40
# 1    122.67     85.60        3.62
# 2    -73.75     75.20        8.05
# 3    161.92     77.81        5.39
# 4     20.04     57.00        6.93
# 5      9.81     73.40        2.24
# 6    147.33     63.00       16.11
# 7    -69.22     35.60       13.87
# 8    -90.35     66.99        4.00
# 9     17.69     74.24        2.62
# 10    -0.29     77.00        5.82
# 11  -151.75     76.01       21.81
# 12   -60.67     78.80        5.82
# 13   -70.91     41.00       23.04
# 14   -68.31     39.20        5.82
# 15   140.83     88.00        9.17
# 16   139.90     22.58       28.57
# 17    81.82     89.87        3.36
# 18   138.62     73.99       14.99
# 19   -37.64     35.60       23.04
# 20   146.27     81.68       16.22
# 21   -67.48     33.80        2.24
# 22    59.39     59.00        4.70
# 23    72.93     83.05       17.11
# 24   -50.48     72.12        2.68
# 25  -114.38     37.40        3.36
# 26   138.60     85.53       18.25
# 27   149.07     77.54       17.00
# 28    18.42     66.00        2.24
# 29    42.50     71.60        5.82
# ..      ...       ...         ...
# 500  -53.28     42.01        6.93
# 501  -78.70     79.48       22.01
# 502  123.76     83.93        6.04
# 503   17.38     74.91        2.21
# 504   76.66     44.42       16.58
# 505  -87.97     77.00        1.74
# 506   40.07     79.41       11.81
# 507  145.42     82.40       17.22
# 508  129.52     75.76        4.81
# 509  118.58    102.20       14.99
# 510    1.49     57.99        1.99
# 511   16.43     69.91        3.44
# 512  149.63     22.78        3.51
# 513  -80.03     74.08        3.22
# 514   43.41     43.88       12.64
# 515   68.36     47.12        9.24
# 516   82.07     49.42       13.35
# 517  -99.88     80.60        2.93
# 518   72.97     50.00       12.21
# 519   22.82     70.43        4.03
# 520 -114.04     66.00       14.18
# 521  -50.82     73.49        3.33
# 522  -99.24     77.00        8.05
# 523  -70.40     57.20       13.87
# 524  -46.03     51.80       32.21
# 525   10.70     44.01        4.70
# 526   49.73     57.05       11.39
# 527   36.93     69.69       11.43
# 528  -73.83     32.00        4.70
# 529  122.30     76.94       21.23
#
# [530 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
weather_cities.plot(kind="scatter", x="Latitude" ,y="Max Temp")

# Incorporate the other graph properties
plt.grid()
plt.title(f"Maximum Temperatures based on Latitude, {cities_df['Date'][0]}")
plt.xlim(-60, 80)
plt.ylim(20, 100)
# Save the figure
plt.savefig("latVsTemp.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_cities["Latitude"], weather_cities["Humidity"], marker="o")
plt.title(f"City Latitude vs. Humidity, {cities_df['Date'][0]} ")
plt.ylabel("Humidity %")
plt.xlabel("Latitude")
plt.xlim(-60, 80)
plt.ylim(20, 100)
plt.grid(True)
# Save the figure
plt.savefig("latVsHumidity.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_cities["Latitude"], weather_cities["Cloudiness"], marker="o")
plt.title(f"City Latitude vs. Cloudiness, {cities_df['Date'][0]} ")
plt.ylabel("Cloudiness %")
plt.xlabel("Latitude")
plt.xlim(-60, 80)
plt.ylim(20, 100)
plt.grid(True)
# Save the figure
plt.savefig("latVsCloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_cities["Latitude"], weather_cities["Wind Speed"], marker="o")
plt.title(f"City Latitude vs.Wind Speed, {cities_df['Date'][0]} ")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.xlim(-60, 80)
plt.ylim(20, 100)
plt.grid(True)
# Save the figure
plt.savefig("latVsWindSpeed.png")

# Show plot
plt.show()
